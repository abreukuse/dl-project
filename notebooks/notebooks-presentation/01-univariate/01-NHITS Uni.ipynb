# %%
# !pip install neuralforecast
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.8/285.8 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 21.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 MB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
from time import time
from neuralforecast import NeuralForecast
from neuralforecast.models import NHITS
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
ROOT = "/content/drive/MyDrive/dl-project"

SEED = 78

horizon = 187
input_size = 187

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv(f"{ROOT}/data/train_data_scaled.csv")
test = pd.read_csv(f"{ROOT}/data/test_data_scaled.csv")

# %%
# Exigência do nixtla
train['unique_id'] = 'slug_flow'
train['ds'] = train['time']
train['y'] = train['liquid_flow_rate']


test['unique_id'] = 'slug_flow'
test['ds'] = test['time']
test['y'] = test['liquid_flow_rate']

# %% [markdown]
# ### Training

# %%
# NHITS: https://nixtlaverse.nixtla.io/neuralforecast/models.nhits.html#nhits

models = [
    NHITS(
        h=horizon,
        input_size=input_size,
        n_blocks=[1, 1, 1],
        mlp_units=[[512, 512], [512, 512], [512, 512]],
        n_pool_kernel_size=[2, 2, 1],
        n_freq_downsample=[4, 2, 1],
        max_steps=500,
        val_check_steps=50,
        early_stop_patience_steps=5,
        random_seed=SEED
    )
]
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 78

# %%
time_spent = {}
nf = NeuralForecast(
    models=models,
    freq=1
)
start_time = time()
nf.fit(df=train, val_size=horizon)
time_spent["training_time"] = time() - start_time
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | blocks       | ModuleList    | 3.0 M  | train
# -------------------------------------------------------
# 3.0 M     Trainable params
# 0         Non-trainable params
# 3.0 M     Total params
# 12.050    Total estimated model params size (MB)
# 34        Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# ...

# %%
print("Training time:", round(time_spent["training_time"], 2), "seconds")
# Out:
# Training time: 233.29 seconds

# %% [markdown]
# ### Predictions

# %%
# Separar o conjunto de teste em pedaços do tamanho do input_size
inputs_for_predicions_list = [
    test.iloc[i:i + input_size]
    for i in range(0, len(test), input_size)
    if i + input_size <= len(test)
]

# %%
# Incluir os últimos 'input_size' dos dados de treino no inicio da lista para fazer a prediçao do primeiro horizonte
inputs_for_predicions_list.insert(0, train.tail(input_size))

# %%
forecasts_list = []
start_time = time()
for input_df in inputs_for_predicions_list:
    forecast = nf.predict(df=input_df)
    forecasts_list.append(forecast)
time_spent["inference_time"] = time() - start_time
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# Predicting: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# ...

# %%
print("Inference time:", round(time_spent["inference_time"], 2), "seconds")
# Out:
# Inference time: 3.27 seconds

# %%
forecasts_output = pd.concat(forecasts_list)

# %%
forecasts_output
# Out:
#      unique_id    ds     NHITS
# 0    slug_flow  1501  0.460089
# 1    slug_flow  1502  0.472038
# 2    slug_flow  1503  0.484056
# 3    slug_flow  1504  0.496832
# 4    slug_flow  1505  0.510607
# ..         ...   ...       ...
# 182  slug_flow  3179  0.268972
# 183  slug_flow  3180  0.272546
# 184  slug_flow  3181  0.276865
# 185  slug_flow  3182  0.280151
# 186  slug_flow  3183  0.280118
#
# [1683 rows x 3 columns]

# %%
ground_truth = pd.concat(inputs_for_predicions_list[1:])[['unique_id', 'ds', 'y']]
ground_truth
# Out:
#       unique_id    ds         y
# 0     slug_flow  1501  0.459397
# 1     slug_flow  1502  0.471283
# 2     slug_flow  1503  0.484231
# 3     slug_flow  1504  0.496564
# 4     slug_flow  1505  0.510421
# ...         ...   ...       ...
# 1491  slug_flow  2992  0.279204
# 1492  slug_flow  2993  0.279133
# 1493  slug_flow  2994  0.279503
# 1494  slug_flow  2995  0.279841
# 1495  slug_flow  2996  0.279759
#
# [1496 rows x 3 columns]

# %%
nhits_results = pd.merge(
    ground_truth,
    forecasts_output,
    on=['unique_id', 'ds'],
    how='left'
)
nhits_results
# Out:
#       unique_id    ds         y     NHITS
# 0     slug_flow  1501  0.459397  0.460089
# 1     slug_flow  1502  0.471283  0.472038
# 2     slug_flow  1503  0.484231  0.484056
# 3     slug_flow  1504  0.496564  0.496832
# 4     slug_flow  1505  0.510421  0.510607
# ...         ...   ...       ...       ...
# 1491  slug_flow  2992  0.279204  0.278713
# 1492  slug_flow  2993  0.279133  0.276791
# 1493  slug_flow  2994  0.279503  0.275687
# 1494  slug_flow  2995  0.279841  0.277323
# 1495  slug_flow  2996  0.279759  0.273071
#
# [1496 rows x 4 columns]

# %% [markdown]
# ### Performance Evaluation

# %%
y_true = nhits_results['y']
y_pred = nhits_results['NHITS']

# %%
print(f"MAE: {mean_absolute_error(y_true, y_pred)}")
# Out:
# MAE: 0.00939895215854641

# %%
print(f"MSE: {mean_squared_error(y_true, y_pred)}")
# Out:
# MSE: 0.001187272852785071

# %%
nhits_results[['y', 'NHITS']].plot(figsize=(15, 5));

# %%
# Salvar modelo
nf.save(path=f"{ROOT}/models/01-univariate/NHITS/")

# %%
nf.save(path=f"{ROOT}/results/01-univariate/nhits_results.csv")
