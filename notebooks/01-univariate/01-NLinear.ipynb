# %%
# Artigo de referência: Time-Series Forecasting of Crude Oil Production Using Hybrid Modeling

# %%
# !pip install feature-engine
# !pip install neuralforecast

# %%
import pandas as pd
from time import time
from neuralforecast import NeuralForecast
from neuralforecast.models import NLinear
from neuralforecast.losses.pytorch import MQLoss
from matplotlib import pyplot as plt

# %%
ROOT = "/content/drive/MyDrive/dl-project"
DATA_FILE = f"{ROOT}/data/01-univariate/Florida_Field_Production_of_Crude_Oil.csv"

SEED = 78

training_proportion = 0.90
horizon = 12
input_size = horizon * 2

time_spent = {}

# %%
data = pd.read_csv(DATA_FILE)

# %%
rename_columns = {
    "Month": "ds",
    "Florida Field Production of Crude Oil Thousand Barrels per Day": "y"
}

data = (
    data
    .rename(columns=rename_columns)
    .assign(ds=lambda df_: pd.to_datetime(df_['ds'], format='%b %Y'))
    .sort_values(by="ds", ascending=True)
    .assign(unique_id="crude_oil_production")
)
data['unique_id'] = 'crude_oil_production'

# %%
data
# Out:
#             ds    y             unique_id
# 530 1981-01-01  116  crude_oil_production
# 529 1981-02-01  113  crude_oil_production
# 528 1981-03-01  102  crude_oil_production
# 527 1981-04-01  102  crude_oil_production
# 526 1981-05-01   98  crude_oil_production
# ..         ...  ...                   ...
# 4   2024-11-01    2  crude_oil_production
# 3   2024-12-01    2  crude_oil_production
# 2   2025-01-01    2  crude_oil_production
# 1   2025-02-01    2  crude_oil_production
# 0   2025-03-01    2  crude_oil_production
#
# [531 rows x 3 columns]

# %%
data.plot(
    x="ds",
    y="y",
    title="Florida Field Production of Crude Oil",
    figsize=(10, 3),
    xlabel="Date",
    ylabel="Production (barrels)"
);

# %%
split_point = int(len(data) * training_proportion)
train_data = data.iloc[:split_point]
test_data = data.iloc[split_point:]

# %%
train_data.shape, test_data.shape
# Out:
# ((477, 3), (54, 3))

# %%
# Treinar NLinear com intervalos de predição
models = [
    NLinear(
        h=horizon,
        input_size=input_size,
        loss=MQLoss(quantiles=[0.05, 0.5, 0.95]),
        max_steps=500,
        val_check_steps=50,
        early_stop_patience_steps=5,
        random_seed=SEED
    )
]
# Out:
# INFO:lightning_fabric.utilities.seed:Seed set to 78

# %%
nf = NeuralForecast(
    models=models,
    freq='M'
)

# %%
start_time = time()
nf.fit(
    df=train_data, val_size=horizon
)
time_spent["training_time-NLinear"] = time() - start_time
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: False, used: False
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MQLoss        | 3      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | linear       | Linear        | 900    | train
# -------------------------------------------------------
# 900       Trainable params
# 3         Non-trainable params
# 903       Total params
# 0.004     Total estimated model params size (MB)
# 4         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_steps=500` reached.

# %%
print("NLinear training time:", round(time_spent["training_time-NLinear"], 1), "seconds")
# Out:
# NLinear training time: 24.9 seconds

# %%
# Junta os últimos 'input_size' pontos do treino com os dados de teste
predictions_input_df = pd.concat([train_data.tail(input_size), test_data])

# %%
# Cria janelas deslizantes do DataFrame para fazer predições
inputs_for_predicions_list = [
    predictions_input_df.iloc[i:i + input_size]
    for i in range(0, len(predictions_input_df) - input_size + 1, horizon)
]

# %%
forecasts_list = []
start_time = time()

for input_df in inputs_for_predicions_list:
    forecast = nf.predict(df=input_df)
    forecasts_list.append(forecast)

time_spent["inference_time-NLinear"] = time() - start_time

# %%
print("NLinear inference time:", round(time_spent["inference_time-NLinear"], 1), "seconds")
# Out:
# NLinear inference time: 0.9 seconds

# %%
forecasts_output = (
    pd.concat(forecasts_list)
    .rename(
        columns={
            "NLinear-lo-90.0": "y_lower",
            "NLinear-median": "y_pred",
            "NLinear-hi-90.0": "y_upper"
        }
    )
    .assign(ds=lambda df_: df_['ds'] + pd.offsets.MonthBegin(0))
)
forecasts_output
# Out:
#                unique_id         ds   y_lower    y_pred   y_upper
# 0   crude_oil_production 2020-10-01  3.650922  3.955357  4.195556
# 1   crude_oil_production 2020-11-01  3.384712  3.616866  3.981434
# 2   crude_oil_production 2020-12-01  4.107571  3.436563  4.128992
# 3   crude_oil_production 2021-01-01  4.050323  4.580504  5.060187
# 4   crude_oil_production 2021-02-01  3.963958  4.279160  3.392756
# 5   crude_oil_production 2021-03-01  3.687940  2.841357  4.357235
# 6   crude_oil_production 2021-04-01  3.566087  3.472565  4.330591
# 7   crude_oil_production 2021-05-01  3.709094  3.261465  4.353595
# 8   crude_oil_production 2021-06-01  3.967975  3.523371  4.636668
# 9   crude_oil_production 2021-07-01  4.077711  2.762984  4.573483
# 10  crude_oil_production 2021-08-01  3.123256  2.724733  4.448010
# 11  crude_oil_production 2021-09-01  3.866763  3.848844  4.190028
# 0   crude_oil_production 2021-10-01  4.133995  4.029886  3.636394
# 1   crude_oil_production 2021-11-01  4.334425  3.923926  4.369087
# 2   crude_oil_production 2021-12-01  3.594179  3.379177  4.439802
# 3   crude_oil_production 2022-01-01  3.976566  4.303023  3.612098
# 4   crude_oil_production 2022-02-01  4.033485  3.961582  3.809483
# 5   crude_oil_production 2022-03-01  4.589851  3.283604  4.093005
# 6   crude_oil_production 2022-04-01  4.057373  3.823006  4.498234
# 7   crude_oil_production 2022-05-01  3.660943  4.130442  3.480060
# 8   crude_oil_production 2022-06-01  3.616520  3.805963  4.655103
# 9   crude_oil_production 2022-07-01  3.940475  4.374807  4.601165
# 10  crude_oil_production 2022-08-01  4.010551  4.646398  3.472791
# 11  crude_oil_production 2022-09-01  4.276660  4.210364  4.527944
# 0   crude_oil_production 2022-10-01  3.347464  2.873194  3.121067
# 1   crude_oil_production 2022-11-01  3.011951  2.576387  3.838699
# 2   crude_oil_production 2022-12-01  2.670940  2.416059  3.303454
# 3   crude_oil_production 2023-01-01  2.369279  2.722532  3.323176
# 4   crude_oil_production 2023-02-01  2.586007  3.357511  2.955737
# 5   crude_oil_production 2023-03-01  2.203635  2.609905  3.016157
# 6   crude_oil_production 2023-04-01  2.606107  3.550689  3.644580
# 7   crude_oil_production 2023-05-01  2.330969  2.729038  3.173838
# 8   crude_oil_production 2023-06-01  2.791730  2.241097  3.857383
# 9   crude_oil_production 2023-07-01  1.993685  2.205158  3.521975
# 10  crude_oil_production 2023-08-01  2.028104  2.994399  3.339975
# 11  crude_oil_production 2023-09-01  2.319296  2.193600  3.589409
# 0   crude_oil_production 2023-10-01  2.703056  2.608442  2.586694
# 1   crude_oil_production 2023-11-01  3.093342  3.366974  3.633783
# 2   crude_oil_production 2023-12-01  2.737580  3.095945  2.942509
# 3   crude_oil_production 2024-01-01  3.145026  2.759303  2.317669
# 4   crude_oil_production 2024-02-01  2.809156  2.371483  3.258743
# 5   crude_oil_production 2024-03-01  2.802331  3.207054  3.198449
# 6   crude_oil_production 2024-04-01  3.315657  2.614345  3.054198
# 7   crude_oil_production 2024-05-01  2.024805  3.357111  2.656749
# 8   crude_oil_production 2024-06-01  2.302707  3.220817  3.275152
# 9   crude_oil_production 2024-07-01  3.034473  2.572456  2.401570
# 10  crude_oil_production 2024-08-01  2.896220  2.730990  2.856313
# 11  crude_oil_production 2024-09-01  3.063371  3.595952  2.836743
# 0   crude_oil_production 2024-10-01  1.833213  1.776149  2.762340
# 1   crude_oil_production 2024-11-01  1.508768  1.546487  3.035036
# 2   crude_oil_production 2024-12-01  2.317828  1.869978  2.145159
# 3   crude_oil_production 2025-01-01  2.081491  1.485974  2.753141
# 4   crude_oil_production 2025-02-01  1.902014  1.632137  1.778714
# 5   crude_oil_production 2025-03-01  0.870208  1.440391  1.778702
# 6   crude_oil_production 2025-04-01  1.743985  2.280393  2.269200
# 7   crude_oil_production 2025-05-01  1.739487  1.698953  2.392272
# 8   crude_oil_production 2025-06-01  1.611368  1.192528  2.274766
# 9   crude_oil_production 2025-07-01  1.327511  1.802183  2.548163
# 10  crude_oil_production 2025-08-01  1.288030  1.663176  2.793121
# 11  crude_oil_production 2025-09-01  1.920913  1.295315  2.139108

# %%
ground_truth = test_data.copy()
ground_truth
# Out:
#            ds  y             unique_id
# 53 2020-10-01  4  crude_oil_production
# 52 2020-11-01  4  crude_oil_production
# 51 2020-12-01  4  crude_oil_production
# 50 2021-01-01  5  crude_oil_production
# 49 2021-02-01  4  crude_oil_production
# 48 2021-03-01  4  crude_oil_production
# 47 2021-04-01  4  crude_oil_production
# 46 2021-05-01  4  crude_oil_production
# 45 2021-06-01  3  crude_oil_production
# 44 2021-07-01  4  crude_oil_production
# 43 2021-08-01  4  crude_oil_production
# 42 2021-09-01  4  crude_oil_production
# 41 2021-10-01  4  crude_oil_production
# 40 2021-11-01  4  crude_oil_production
# 39 2021-12-01  4  crude_oil_production
# 38 2022-01-01  3  crude_oil_production
# 37 2022-02-01  4  crude_oil_production
# 36 2022-03-01  4  crude_oil_production
# 35 2022-04-01  4  crude_oil_production
# 34 2022-05-01  4  crude_oil_production
# 33 2022-06-01  2  crude_oil_production
# 32 2022-07-01  3  crude_oil_production
# 31 2022-08-01  3  crude_oil_production
# 30 2022-09-01  3  crude_oil_production
# 29 2022-10-01  3  crude_oil_production
# 28 2022-11-01  3  crude_oil_production
# 27 2022-12-01  3  crude_oil_production
# 26 2023-01-01  3  crude_oil_production
# 25 2023-02-01  1  crude_oil_production
# 24 2023-03-01  2  crude_oil_production
# 23 2023-04-01  3  crude_oil_production
# 22 2023-05-01  3  crude_oil_production
# 21 2023-06-01  3  crude_oil_production
# 20 2023-07-01  3  crude_oil_production
# 19 2023-08-01  3  crude_oil_production
# 18 2023-09-01  3  crude_oil_production
# 17 2023-10-01  3  crude_oil_production
# 16 2023-11-01  3  crude_oil_production
# 15 2023-12-01  3  crude_oil_production
# 14 2024-01-01  3  crude_oil_production
# 13 2024-02-01  2  crude_oil_production
# 12 2024-03-01  3  crude_oil_production
# 11 2024-04-01  2  crude_oil_production
# 10 2024-05-01  3  crude_oil_production
# 9  2024-06-01  3  crude_oil_production
# 8  2024-07-01  2  crude_oil_production
# 7  2024-08-01  3  crude_oil_production
# 6  2024-09-01  2  crude_oil_production
# 5  2024-10-01  2  crude_oil_production
# 4  2024-11-01  2  crude_oil_production
# 3  2024-12-01  2  crude_oil_production
# 2  2025-01-01  2  crude_oil_production
# 1  2025-02-01  2  crude_oil_production
# 0  2025-03-01  2  crude_oil_production

# %%
nlinear_results = pd.merge(
    ground_truth,
    forecasts_output,
    on=['unique_id', 'ds'],
    how='inner'
)
nlinear_results
# Out:
#            ds  y             unique_id   y_lower    y_pred   y_upper
# 0  2020-10-01  4  crude_oil_production  3.650922  3.955357  4.195556
# 1  2020-11-01  4  crude_oil_production  3.384712  3.616866  3.981434
# 2  2020-12-01  4  crude_oil_production  4.107571  3.436563  4.128992
# 3  2021-01-01  5  crude_oil_production  4.050323  4.580504  5.060187
# 4  2021-02-01  4  crude_oil_production  3.963958  4.279160  3.392756
# 5  2021-03-01  4  crude_oil_production  3.687940  2.841357  4.357235
# 6  2021-04-01  4  crude_oil_production  3.566087  3.472565  4.330591
# 7  2021-05-01  4  crude_oil_production  3.709094  3.261465  4.353595
# 8  2021-06-01  3  crude_oil_production  3.967975  3.523371  4.636668
# 9  2021-07-01  4  crude_oil_production  4.077711  2.762984  4.573483
# 10 2021-08-01  4  crude_oil_production  3.123256  2.724733  4.448010
# 11 2021-09-01  4  crude_oil_production  3.866763  3.848844  4.190028
# 12 2021-10-01  4  crude_oil_production  4.133995  4.029886  3.636394
# 13 2021-11-01  4  crude_oil_production  4.334425  3.923926  4.369087
# 14 2021-12-01  4  crude_oil_production  3.594179  3.379177  4.439802
# 15 2022-01-01  3  crude_oil_production  3.976566  4.303023  3.612098
# 16 2022-02-01  4  crude_oil_production  4.033485  3.961582  3.809483
# 17 2022-03-01  4  crude_oil_production  4.589851  3.283604  4.093005
# 18 2022-04-01  4  crude_oil_production  4.057373  3.823006  4.498234
# 19 2022-05-01  4  crude_oil_production  3.660943  4.130442  3.480060
# 20 2022-06-01  2  crude_oil_production  3.616520  3.805963  4.655103
# 21 2022-07-01  3  crude_oil_production  3.940475  4.374807  4.601165
# 22 2022-08-01  3  crude_oil_production  4.010551  4.646398  3.472791
# 23 2022-09-01  3  crude_oil_production  4.276660  4.210364  4.527944
# 24 2022-10-01  3  crude_oil_production  3.347464  2.873194  3.121067
# 25 2022-11-01  3  crude_oil_production  3.011951  2.576387  3.838699
# 26 2022-12-01  3  crude_oil_production  2.670940  2.416059  3.303454
# 27 2023-01-01  3  crude_oil_production  2.369279  2.722532  3.323176
# 28 2023-02-01  1  crude_oil_production  2.586007  3.357511  2.955737
# 29 2023-03-01  2  crude_oil_production  2.203635  2.609905  3.016157
# 30 2023-04-01  3  crude_oil_production  2.606107  3.550689  3.644580
# 31 2023-05-01  3  crude_oil_production  2.330969  2.729038  3.173838
# 32 2023-06-01  3  crude_oil_production  2.791730  2.241097  3.857383
# 33 2023-07-01  3  crude_oil_production  1.993685  2.205158  3.521975
# 34 2023-08-01  3  crude_oil_production  2.028104  2.994399  3.339975
# 35 2023-09-01  3  crude_oil_production  2.319296  2.193600  3.589409
# 36 2023-10-01  3  crude_oil_production  2.703056  2.608442  2.586694
# 37 2023-11-01  3  crude_oil_production  3.093342  3.366974  3.633783
# 38 2023-12-01  3  crude_oil_production  2.737580  3.095945  2.942509
# 39 2024-01-01  3  crude_oil_production  3.145026  2.759303  2.317669
# 40 2024-02-01  2  crude_oil_production  2.809156  2.371483  3.258743
# 41 2024-03-01  3  crude_oil_production  2.802331  3.207054  3.198449
# 42 2024-04-01  2  crude_oil_production  3.315657  2.614345  3.054198
# 43 2024-05-01  3  crude_oil_production  2.024805  3.357111  2.656749
# 44 2024-06-01  3  crude_oil_production  2.302707  3.220817  3.275152
# 45 2024-07-01  2  crude_oil_production  3.034473  2.572456  2.401570
# 46 2024-08-01  3  crude_oil_production  2.896220  2.730990  2.856313
# 47 2024-09-01  2  crude_oil_production  3.063371  3.595952  2.836743
# 48 2024-10-01  2  crude_oil_production  1.833213  1.776149  2.762340
# 49 2024-11-01  2  crude_oil_production  1.508768  1.546487  3.035036
# 50 2024-12-01  2  crude_oil_production  2.317828  1.869978  2.145159
# 51 2025-01-01  2  crude_oil_production  2.081491  1.485974  2.753141
# 52 2025-02-01  2  crude_oil_production  1.902014  1.632137  1.778714
# 53 2025-03-01  2  crude_oil_production  0.870208  1.440391  1.778702

# %%
# Salvar Resultados
nlinear_results.to_csv(f"{ROOT}/results/03-multivariate/nlinear_results.csv", index=False)

# %%
# Plotar a previsão com intervalos de predição
plt.style.use('seaborn-v0_8-whitegrid')
fig, ax = plt.subplots(figsize=(15, 3))

# Plotar dados históricos (últimos 3x passos do horizonte para contexto)
plot_df = pd.concat([train_data.tail(3 * horizon), test_data]).set_index('ds')
plot_df['y'].plot(ax=ax, label='Observed Data')

# Plotar a previsão
forecasts_plot = forecasts_output.set_index('ds')
forecasts_plot['y_pred'].plot(ax=ax, label='N-Linear Forecast (Median)', color='blue')

# Sombrear o intervalo de predição
ax.fill_between(
   forecasts_plot.index,
   forecasts_plot['y_lower'],
   forecasts_plot['y_upper'],
   color='blue',
   alpha=0.2,
   label='90% Prediction Interval'
)

ax.set_title('Florida Crude Oil Production: N-Linear Forecast')
ax.set_ylabel('Thousand Barrels per Day')
ax.set_xlabel('Date')
ax.legend(loc='upper right')
ax.grid(True)
plt.show()
